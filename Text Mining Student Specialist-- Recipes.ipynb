# %% [markdown]
# # Top Ingredients Used by Tori Avey
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#gather">Gathering Data</a></li>
# <li><a href="#clean">Cleaning Data</a></li>
# <li><a href="#analysis">Analysis</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# In this project I scraped 168 recipes from my favorite recipe blog using BeautifulSoup. I then cleaned the data, by first getting rid rows that were highly specific recipes like soup stock or different ways to prepare eggplant instead of creating a full dish, second, checking for items that are objects instead of food items, and finally getting rid of unneccessary parts of information in the text (for example, dropping the 'to taste' in 'salt, to taste'). I did some analysis in the end to uncover the ingredients, the number of times each ingredient was shown, and the proportion of recipes that each ingredient appears in (not counting when the item appears more than once per recipe, which it turns out happens often!).
#
# The objectives here are as follows:
#
# <ul>
#     <li><b>scraping data</b>: scrape at least 100 recipes</li>
#     <li><b>cleaning data</b>: clean data for further calculation</li>
#     <li><b>calculating</b>: assess which are the ten most commonly used ingredients</li>
# </ul>
#
# For a recipe blog I have chosen https://toriavey.com/. I highly recommend her pretzel challah: https://toriavey.com/toris-kitchen/pretzel-challah/

# %%
import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
import re
import numpy as np

# %% [markdown]
# <a id='gather'></a>
# ## Gathering Data

# %% [markdown]
# <div class="alert alert-block alert-info">
# In this section I will first set up some functions to scrape data from Tori Avey's website. Because scraping is very specific to the layout of her blog posts, I am creating functions that could be partially reused, but the function that calls each of them will not use any abstraction. Following, I will implement the wrangling functions, check that the data is at least partially correct, and save it to an csv.
# </div>

# %% [markdown]
# Set up wrangling functions:

# %%
def get_recipe_genres():
    '''No input because this is specific to the layout of this particular website, returns list of strings
       that signify the urls of each genre listed on her site'''
    # Get the homepage with all available recipe type links and make a soup
    url = 'https://toriavey.com/recipes/'
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    #find the url for each recipe categories 
    recipe_type_urls = []
    recipeList = soup.find("div", class_="recipes-index")
    for catBox in recipeList.find_all("div", class_="cat-box"):
        recipe_type_urls.append(catBox.a.get('href'))
    return recipe_type_urls

# %%
def get_recipe_urls(recipe_type_urls):
    '''Input is a list of url strings, output is a list of url strings that are enumerated on the recipe genre page'''
    recipe_urls = []
    for genre_url in recipe_type_urls:
        recipe_genre_page = requests.get(genre_url)
        genre_soup = BeautifulSoup(recipe_genre_page.content, 'html.parser')
        main_content = genre_soup.find("main")
        #some of these might be ads and not have the same layout
        if not main_content:
            continue
        for recipe in main_content.find_all("article"):
            recipe_urls.append(recipe.a.get('href'))
    return recipe_urls

# %%
def get_recipe_info(recipe_urls):
    '''Input is a list of url strings, output is a nested list indicating url, title, and ingredient for each element'''
    csv_data = []
    for recipe_url in recipe_urls:
        recipe_page = requests.get(recipe_url)
        recipe_soup = BeautifulSoup(recipe_page.content, 'html.parser')
        title = recipe_soup.find("h2", class_="wprm-recipe-name")
        #some of these might be ads and not have the same layout
        if not title:
            continue
        title = title.text
        ingredients = recipe_soup.find_all("ul", class_="wprm-recipe-ingredients")
        for ingredient_list in ingredients:
            for ingredient in ingredient_list.find_all("li"):
                ingredient_element = ingredient.find("span", class_="wprm-recipe-ingredient-name")
                if ingredient_element.text:
                    ingredient_name = ingredient_element.text.strip()
                else:
                    continue
                csv_line = [recipe_url]
                csv_line.append(title)
                csv_line.append(ingredient_name)
                csv_data.append(csv_line)
    return csv_data

# %%
def get_toris_recipes():
    recipe_genre_urls = get_recipe_genres()
    recipe_urls = get_recipe_urls(recipe_genre_urls)
    csv_data = get_recipe_info(recipe_urls)
    return csv_data

# %% [markdown]
# Scrape data and check the first line

# %%
recipe_data = get_toris_recipes()
print(len(recipe_data))
print(recipe_data[0])
# Out:
# 5283
# ['https://toriavey.com/toris-kitchen/aunt-bevs-vegetarian-chopped-liver/', "Aunt Bev's Vegetarian Chopped Liver", 'vegetable oil']

# %%
def create_csv(filename, header, csv_data):
    '''Takes in a string for a filename, a list for a header, and a list of lists for csv data
       No returns, a file is created with the listed filename'''
    with open(filename, 'w', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerows(csv_data)

# %%
csv_header = ['url', 'name', 'ingredient']
create_csv('rawData.csv', csv_header, recipe_data)

# %%
rawData_pd = pd.read_csv('rawData.csv')
rawData_pd.head(7)
# Out:
#                                                  url  \
# 0  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 1  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 2  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 3  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 4  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 5  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 6  https://toriavey.com/toris-kitchen/panko-corn-...
#
#                                   name                ingredient
# 0  Aunt Bev's Vegetarian Chopped Liver             vegetable oil
# 1  Aunt Bev's Vegetarian Chopped Liver                    onion,
# 2  Aunt Bev's Vegetarian Chopped Liver          chopped walnuts,
# 3  Aunt Bev's Vegetarian Chopped Liver  peeled hard boiled eggs,
# 4  Aunt Bev's Vegetarian Chopped Liver                     peas,
# 5  Aunt Bev's Vegetarian Chopped Liver  Salt and pepper to taste
# 6      Panko Corn and Pepper Schnitzel       ears corn, shucked,

# %% [markdown]
# <a href="#clean"></a>
# ## Cleaning Data

# %% [markdown]
# <div class="alert alert-block alert-info">
# In this section I did some preliminary exploration to come up with the table of issues listed below, and dealt with them one by one.<br/><br/>
# For the names column, I realized that the items starting with "how to" looked more like basic ingredients rather than full recipes so I deleted the columns with those listed.
#     <br/><br/>The ingredients column needed some further investigation so I looked at them a bit more and decided that it would be better to keep both options when it says something like "barcardi or havana rum" because it could be interesting to see how often the same substitution pairs come up. I also saw that if a line starts with a capital 'A' it is always an object while a lowercase 'a' is used before food items (like 'a vanilla bean' vs 'A saucepan') so I just got rid of all the lines that start with a capital A. I also deleted anything that comes after a comma or parenthesis because this is usually followed by information that is not relevant.
# <br/><br/>
#
# I stored all of the new information in a clean dataframe called clean_df and saved it to a csv using the method from above.
# </div>

# %% [markdown]
# | Urls | Name | Ingredient |
# | --- | --- | --- |
# | --- | Some recipes start with "How to" instead of the recipe name | There is sometimes extra information after a ',' or ')' |
# | --- | In one "how to" there is also a '-' with more information following | I see 'A saucepan' on line 3389 |
# | --- | --- | Sometimes see "to taste" or "for frying" or "for garnish" ect |
# | --- | --- | Line 5271 has a 'bacardi or havana rum' maybe we can look at items with 'or' to assess more |

# %%
rawData_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   url         5283 non-null   object
#  1   name        5283 non-null   object
#  2   ingredient  5283 non-null   object
# dtypes: object(3)
# memory usage: 123.9+ KB

# %%
len(rawData_pd["name"].unique())
# Out:
# 176

# %%
rawData_pd.sample(50)
# Out:
#                                                     url  \
# 5016  https://toriavey.com/toris-kitchen/julia-child...
# 2458  https://toriavey.com/toris-kitchen/holiday-bri...
# 2608  https://toriavey.com/toris-kitchen/grilled-veg...
# 4219  https://toriavey.com/toris-kitchen/roasted-veg...
# 1079  https://toriavey.com/toris-kitchen/grilled-veg...
# 2328  https://toriavey.com/toris-kitchen/honey-garli...
# 3832  https://toriavey.com/toris-kitchen/grilled-veg...
# 645   https://toriavey.com/toris-kitchen/matcha-gree...
# 529   https://toriavey.com/toris-kitchen/apple-date-...
# 3612  https://toriavey.com/toris-kitchen/kasha-varni...
# 5034  https://toriavey.com/toris-kitchen/classic-che...
# 5189   https://toriavey.com/toris-kitchen/tomato-frost/
# 5083  https://toriavey.com/toris-kitchen/moroccan-st...
# 639   https://toriavey.com/toris-kitchen/lemon-ginge...
# 4924  https://toriavey.com/toris-kitchen/peach-and-b...
# 1530  https://toriavey.com/toris-kitchen/mediterrane...
# 2689  https://toriavey.com/toris-kitchen/mediterrane...
# 2700  https://toriavey.com/toris-kitchen/salmon-stra...
# 1471  https://toriavey.com/toris-kitchen/date-truffles/
# 2791  https://toriavey.com/toris-kitchen/oven-roaste...
# 4092  https://toriavey.com/toris-kitchen/grilled-veg...
# 995   https://toriavey.com/toris-kitchen/date-truffles/
# 2152  https://toriavey.com/toris-kitchen/roasted-veg...
# 570   https://toriavey.com/toris-kitchen/kobete-seph...
# 3772  https://toriavey.com/toris-kitchen/boozy-orang...
# 1177  https://toriavey.com/toris-kitchen/mediterrane...
# 153   https://toriavey.com/toris-kitchen/smoky-panko...
# 2007  https://toriavey.com/toris-kitchen/garlicky-ka...
# 4546  https://toriavey.com/toris-kitchen/rotisserie-...
# 3148  https://toriavey.com/toris-kitchen/oven-roaste...
# 3569  https://toriavey.com/toris-kitchen/homemade-ch...
# 1725  https://toriavey.com/toris-kitchen/rainbow-isr...
# 3027  https://toriavey.com/toris-kitchen/roasted-por...
# 4992  https://toriavey.com/toris-kitchen/date-honey-...
# 2150  https://toriavey.com/toris-kitchen/roasted-veg...
# 5204  https://toriavey.com/toris-kitchen/history-pic...
# 1354  https://toriavey.com/toris-kitchen/baby-lox-po...
# 4047  https://toriavey.com/toris-kitchen/garlicky-ka...
# 1121  https://toriavey.com/toris-kitchen/roasted-por...
# 678   https://toriavey.com/toris-kitchen/how-to-make...
# 3873  https://toriavey.com/toris-kitchen/rainbow-isr...
# 2193  https://toriavey.com/toris-kitchen/baby-lox-po...
# 1294  https://toriavey.com/toris-kitchen/roasted-veg...
# 5065  https://toriavey.com/toris-kitchen/pineapple-r...
# 336   https://toriavey.com/toris-kitchen/cinnamon-ba...
# 4872  https://toriavey.com/toris-kitchen/pumpkin-spi...
# 3280  https://toriavey.com/toris-kitchen/rosh-hashan...
# 1201  https://toriavey.com/toris-kitchen/salmon-stra...
# 59    https://toriavey.com/toris-kitchen/jewish-swee...
# 2717  https://toriavey.com/toris-kitchen/moroccan-st...
#
#                                                    name  \
# 5016       Julia Child's Easy Blender Hollandaise Sauce
# 2458                                    Holiday Brisket
# 2608                            Grilled Vegetable Salad
# 4219                                 Vegetable Moussaka
# 1079                            Grilled Vegetable Salad
# 2328                               Honey Garlic Chicken
# 3832                            Grilled Vegetable Salad
# 645                              Matcha Green Tea Latte
# 529                               Apple Date Rose Tarts
# 3612                  Kasha Varnishkes (Kasha and Bows)
# 5034                                 Classic Cheesecake
# 5189                                       Tomato Frost
# 5083                  Moroccan-Style Vegetable Couscous
# 639                 Lemon Ginger Cider Vinegar Infusion
# 4924                          Peach and Blueberry Crisp
# 1530                 Mediterranean Tuna Hummus Crostini
# 2689  Sardine Pasta with Lemon, Capers and Chili Flakes
# 2700       Salmon with Strawberries, Balsamic and Basil
# 1471                                      Date Truffles
# 2791                       Oven Roasted Root Vegetables
# 4092                            Grilled Vegetable Salad
# 995                                       Date Truffles
# 2152                                 Vegetable Moussaka
# 570                  Kobete - Sephardic Savory Meat Pie
# 3772               Boozy Orange Blossom Cranberry Sauce
# 1177  Sardine Pasta with Lemon, Capers and Chili Flakes
# 153                         Smoky Panko Schnitzel Bites
# 2007          Kale Caesar Salad with Parmesan and Panko
# 4546                       Rotisserie Chicken Rice Soup
# 3148                       Oven Roasted Root Vegetables
# 3569                        Swedish Chicken and Noodles
# 1725                              Rainbow Israeli Salad
# 3027    Roasted Portobello Pepper Caps with Goat Cheese
# 4992                                Date Honey Nut Cake
# 2150                                 Vegetable Moussaka
# 5204                                     Blueberry Cake
# 1354                        Baby Lox Potatoes Appetizer
# 4047          Kale Caesar Salad with Parmesan and Panko
# 1121    Roasted Portobello Pepper Caps with Goat Cheese
# 678   How to Make Coconut Milk & Gluten Free Coconut...
# 3873                              Rainbow Israeli Salad
# 2193                        Baby Lox Potatoes Appetizer
# 1294                                 Vegetable Moussaka
# 5065                      Pineapple Raisin Noodle Kugel
# 336                                      Cinnamon Babka
# 4872                                 Pumpkin Spice Cake
# 3280                              Rosh Hashanah Sangria
# 1201       Salmon with Strawberries, Balsamic and Basil
# 59                      Jewish Sweet and Sour Meatballs
# 2717                  Moroccan-Style Vegetable Couscous
#
#                                              ingredient
# 5016                                    unsalted butter
# 2458                         peeled whole garlic cloves
# 2608                                  fresh lemon juice
# 4219                                    Salt and pepper
# 1079                             extra virgin olive oil
# 2328                             extra virgin olive oil
# 3832  yellow squash (2 medium), halved lengthwise, e...
# 645                                           hot water
# 529                                           hot water
# 3612                                     fresh parsley,
# 5034                                           cinnamon
# 5189                                      celery leaves
# 5083                         low sodium vegetable broth
# 639                                           hot water
# 4924  large ripe peaches, pitted and sliced into 12-...
# 1530         Genova Tonno Solid Light Tuna in Olive Oil
# 2689                                         lemon zest
# 2700                                fresh strawberries,
# 1471                                       pitted dates
# 2791                                       ground cumin
# 4092                             extra virgin olive oil
# 995                    dried flaked or shredded coconut
# 2152                            all purpose white flour
# 570                                     Salt and pepper
# 3772                                           cinnamon
# 1177                          crushed red pepper flakes
# 153                                               honey
# 2007                               Worcestershire sauce
# 4546                                white or brown rice
# 3148                                      large carrots
# 3569                                              flour
# 1725               yellow bell pepper, seeded and diced
# 3027                                     smoked paprika
# 4992                                      baking powder
# 2150                 grated pecorino or parmesan cheese
# 5204                                     butter, melted
# 1354                                       cream cheese
# 4047                                        curly kale,
# 1121                               portobello mushrooms
# 678              Vanilla extract and/or salt (optional)
# 3873        small red cabbage, shredded in small pieces
# 2193            small red new potatoes or baby potatoes
# 1294                            diced ripe red tomatoes
# 5065                                           cinnamon
# 336                                   all purpose flour
# 4872                                           allspice
# 3280                                              honey
# 1201                                              salt,
# 59                                              cayenne
# 2717                                           cinnamon

# %% [markdown]
# Let's double check that these urls are in good shape

# %%
rawData_pd["url"][0]
# Out:
# 'https://toriavey.com/toris-kitchen/aunt-bevs-vegetarian-chopped-liver/'

# %% [markdown]
# That looks good to me, so let's take a closer look at what's happening with these names.

# %%
recipe_names = rawData_pd['name'].tolist()
indices_to_drop = []
for index, name in enumerate(recipe_names):
    if name[0:4] == "How ":
        print(name)
        indices_to_drop.append(index)
# Out:
# How to Roast Garlic - Five Easy Methods
# How to Roast Garlic - Five Easy Methods
# How to Make Coconut Milk & Gluten Free Coconut Flour
# How to Make Coconut Milk & Gluten Free Coconut Flour
# How to Make Coconut Milk & Gluten Free Coconut Flour
# How to Make Coconut Milk & Gluten Free Coconut Flour
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Roast Cauliflower
# How to Roast Cauliflower
# How to Roast Cauliflower
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Make Fluffy Moist Scrambled Eggs
# How to Roast Garlic - Five Easy Methods
# How to Roast Garlic - Five Easy Methods
# How to Make Coconut Milk & Gluten Free Coconut Flour
# How to Make Coconut Milk & Gluten Free Coconut Flour
# How to Make Coconut Milk & Gluten Free Coconut Flour
# How to Make Coconut Milk & Gluten Free Coconut Flour
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Fry Eggplant with Less Oil
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Homemade Chicken Stock - 4 Easy Methods
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Candied Lemon Peels
# How to Make Homemade Butter
# How to Make Homemade Butter
# How to Make Homemade Butter
# How to Make Homemade Butter

# %% [markdown]
# On second thought, these all look like ways to prepare basic ingredients instead of recipes so I think it would be better if we drop the columns with these items

# %%
clean_df = rawData_pd.copy()

# %%
clean_df = clean_df.drop(indices_to_drop)

# %%
print(clean_df.shape[0], rawData_pd.shape[0])
# Out:
# 5120 5283

# %% [markdown]
# Finally let's go through all the ingredients

# %%
def drop_anything_after_delimiter(ingredient):
    split = list(filter(None, re.split(r'(\,|\()', item)))
    return split[0]

# %%
def drop_excess_tos_and_fors(ingredient):
    split = ingredient.split(" ")
    if len(split) > 2 and (split[-2] == 'for' or split[-2] == 'to'):
        return " ".join(split[:-2])
    return ingredient

# %%
ingredients = clean_df['ingredient'].tolist()
clean_ingredients = []
indices_to_drop = []
for index, item in enumerate(ingredients):
    if split[0] == "A":
        indices_to_drop.append(index)
    no_delimiters = drop_anything_after_delimiter(item)
    final = drop_excess_tos_and_fors(no_delimiters)
    clean_ingredients.append(str(final))

# %%
clean_df = clean_df.drop(indices_to_drop)

# %%
n = clean_df.columns[2]
clean_df.drop(n, axis = 1, inplace = True)
clean_df[n] = clean_ingredients

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5120 entries, 0 to 5282
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   url         5120 non-null   object
#  1   name        5120 non-null   object
#  2   ingredient  5120 non-null   object
# dtypes: object(3)
# memory usage: 289.0+ KB

# %%
clean_df.sample(50)
# Out:
#                                                     url  \
# 4928  https://toriavey.com/toris-kitchen/peach-and-b...
# 5254  https://toriavey.com/toris-kitchen/calumet-par...
# 4725  https://toriavey.com/toris-kitchen/fennel-appl...
# 3763  https://toriavey.com/how-to/easy-blender-lemon...
# 705   https://toriavey.com/toris-kitchen/watermelon-...
# 1072  https://toriavey.com/toris-kitchen/middle-east...
# 3273  https://toriavey.com/toris-kitchen/garlicky-ka...
# 2867  https://toriavey.com/toris-kitchen/lemony-mari...
# 4526  https://toriavey.com/toris-kitchen/easy-caulif...
# 171   https://toriavey.com/toris-kitchen/classic-hum...
# 612   https://toriavey.com/toris-kitchen/pomegranate...
# 4436  https://toriavey.com/toris-kitchen/chickpea-ka...
# 1241  https://toriavey.com/toris-kitchen/moroccan-st...
# 3801  https://toriavey.com/toris-kitchen/hawayej-spi...
# 3249  https://toriavey.com/toris-kitchen/the-purim-p...
# 4356  https://toriavey.com/toris-kitchen/sweet-potat...
# 336   https://toriavey.com/toris-kitchen/cinnamon-ba...
# 1105  https://toriavey.com/toris-kitchen/panko-corn-...
# 4933  https://toriavey.com/toris-kitchen/stovetop-tz...
# 3568  https://toriavey.com/toris-kitchen/rainbow-isr...
# 4290  https://toriavey.com/toris-kitchen/mediterrane...
# 3192  https://toriavey.com/toris-kitchen/israeli-sal...
# 1901  https://toriavey.com/toris-kitchen/salmon-stra...
# 1032   https://toriavey.com/toris-kitchen/key-lime-pie/
# 872   https://toriavey.com/toris-kitchen/coffee-moch...
# 4598  https://toriavey.com/toris-kitchen/chilled-gre...
# 1787  https://toriavey.com/toris-kitchen/garlicky-ka...
# 607   https://toriavey.com/toris-kitchen/pomegranate...
# 1588  https://toriavey.com/toris-kitchen/stovetop-tz...
# 2801  https://toriavey.com/toris-kitchen/herb-braise...
# 1535  https://toriavey.com/toris-kitchen/mediterrane...
# 744   https://toriavey.com/toris-kitchen/pumpkin-spi...
# 4018  https://toriavey.com/toris-kitchen/red-rice-an...
# 1981  https://toriavey.com/toris-kitchen/vegan-stuff...
# 1305  https://toriavey.com/toris-kitchen/roasted-veg...
# 711   https://toriavey.com/toris-kitchen/vanilla-ber...
# 5181  https://toriavey.com/toris-kitchen/gary-cooper...
# 3370  https://toriavey.com/toris-kitchen/corkys-oven...
# 2411  https://toriavey.com/toris-kitchen/homemade-ch...
# 3529  https://toriavey.com/toris-kitchen/audrey-hepb...
# 3694  https://toriavey.com/toris-kitchen/chopped-liver/
# 5231  https://toriavey.com/toris-kitchen/clotted-cre...
# 1697  https://toriavey.com/toris-kitchen/israeli-sal...
# 933   https://toriavey.com/toris-kitchen/king-cake-r...
# 2447  https://toriavey.com/toris-kitchen/kasha-varni...
# 2008  https://toriavey.com/toris-kitchen/garlicky-ka...
# 3424  https://toriavey.com/toris-kitchen/pineapple-r...
# 3638  https://toriavey.com/toris-kitchen/quinoa-blac...
# 3939  https://toriavey.com/toris-kitchen/roasted-egg...
# 3752  https://toriavey.com/toris-kitchen/honey-prese...
#
#                                                  name  \
# 4928                        Peach and Blueberry Crisp
# 5254                               Parker House Rolls
# 4725          Fennel Apple Salad with Tahini Dressing
# 3763                                       Lemon Curd
# 705               Watermelon Rosemary Frozen Lemonade
# 1072            Middle Eastern Roasted Vegetable Rice
# 3273        Kale Caesar Salad with Parmesan and Panko
# 2867                 Lemony Marinated Chicken Skewers
# 4526                            Easy Cauliflower Soup
# 171                                    Classic Hummus
# 612                               Pomegranate Martini
# 4436       Chickpea Kale and Fire Roasted Tomato Soup
# 1241                Moroccan-Style Vegetable Couscous
# 3801                              Hawayej Spice Blend
# 3249                                 The Purim Pucker
# 4356                         Autumn Sweet Potato Soup
# 336                                    Cinnamon Babka
# 1105                  Panko Corn and Pepper Schnitzel
# 4933                                 Stovetop Tzimmes
# 3568                            Rainbow Israeli Salad
# 4290                        Mediterranean 7 Layer Dip
# 3192                                    Israeli Salad
# 1901     Salmon with Strawberries, Balsamic and Basil
# 1032                                     Key Lime Pie
# 872                          Coffee Mocha Pudding Pie
# 4598                        Chilled Greek Yogurt Soup
# 1787        Kale Caesar Salad with Parmesan and Panko
# 607                               Pomegranate Martini
# 1588                                 Stovetop Tzimmes
# 2801                         Herb Braised Lamb Shanks
# 1535               Mediterranean Tuna Hummus Crostini
# 744                                Pumpkin Spice Cake
# 4018       Red Rice and Beet Cakes with Honey Mustard
# 1981                       Vegan Stuffed Acorn Squash
# 1305                               Vegetable Moussaka
# 711                   Vanilla Berry Sparkling Sangria
# 5181           Gary Cooper's Buttermilk Griddle Cakes
# 3370                        Oven Barbecued Short Ribs
# 2411                      Swedish Chicken and Noodles
# 3529  Audrey Hepburn’s Favorite Spaghetti al Pomodoro
# 3694                                    Chopped Liver
# 5231                 Clotted Cream and English Scones
# 1697          Israeli Salad with Feta Cheese and Mint
# 933                                         King Cake
# 2447                Kasha Varnishkes (Kasha and Bows)
# 2008        Kale Caesar Salad with Parmesan and Panko
# 3424                    Pineapple Raisin Noodle Kugel
# 3638                  Quinoa Black Bean Burrito Bowls
# 3939           Roasted Eggplant Yogurt Dip - Moutabal
# 3752                         Honey Preserved Kumquats
#
#                                       ingredient
# 4928  aged balsamic vinegar or fresh lemon juice
# 5254                       Calumet Baking Powder
# 4725                                   olive oil
# 3763                                        eggs
# 705           chilled seedless watermelon chunks
# 1072                                    cilantro
# 3273                                       water
# 2867                                    turmeric
# 4526                             Unsalted butter
# 171                                        cumin
# 612                                    ice cubes
# 4436                      extra virgin olive oil
# 1241                              golden raisins
# 3801                             ground turmeric
# 3249                          chopped fresh mint
# 4356                                       cumin
# 336                            all purpose flour
# 1105                              smoked paprika
# 4933                                dried apples
# 3568                                        salt
# 4290            fresh flat leaf parsley or basil
# 3192                                minced onion
# 1901                                        salt
# 1032                                 Lime slices
# 872                                       butter
# 4598                Freshly squeezed lemon juice
# 1787                   crushed red pepper flakes
# 607                            pomegranate seeds
# 1588                                 orange yams
# 2801                                whole cloves
# 1535                                       pesto
# 744                                         salt
# 4018          lightly packed finely chopped dill
# 1981                  fresh chopped thyme leaves
# 1305                                      nutmeg
# 711                                        water
# 5181                                         egg
# 3370                                 kosher salt
# 2411                                        eggs
# 3529                                        Salt
# 3694                                    gribenes
# 5231                                 heavy cream
# 1697                           ripe red tomatoes
# 933                              unsalted butter
# 2447                                    schmaltz
# 2008                                        salt
# 3424                             unsalted butter
# 3638                          cooked black beans
# 3939                                 lemon juice
# 3752                                       honey

# %%
clean_df.to_csv('cleanData.csv', index=False)

# %% [markdown]
# <a id='analysis'></a>
# ## Analysis

# %% [markdown]
# <div class="alert alert-block alert-info">
# For our results csv we wanted to have a list of ingredients, their value count overall, and the proportion of recipes in which the ingredient appears. <br/><br/>
# The first two columns are fairly straightforward, but when I originally tried to find the proportion of recipes in which each ingredient appears, I noticed that the top ingredient, salt, appeared 1.6X per recipe. I did a quick scan of Tori's website and it turns out many of her recipes are subdivided into a few smaller recipes. For example, in my suggestion of her preztel challah, she has a section for the challah itself and also a section for egg wash-- and, just as I suspected, salt shows up in both, making it give this recipe double the salt intake for my dataframe. <br/><br/>
# I rewrote the function to only count ingredients for each recipe once. Following, salt was still the most common ingredient, but its proportion had been cut to only a little over half of the recipes. The top 20 results looked reasonable to me, so I sent them to the final csv
# </div>

# %%
results_df = clean_df.copy()

# %%
results_df.head()
# Out:
#                                                  url  \
# 0  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 1  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 2  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 3  https://toriavey.com/toris-kitchen/aunt-bevs-v...
# 4  https://toriavey.com/toris-kitchen/aunt-bevs-v...
#
#                                   name               ingredient
# 0  Aunt Bev's Vegetarian Chopped Liver            vegetable oil
# 1  Aunt Bev's Vegetarian Chopped Liver                    onion
# 2  Aunt Bev's Vegetarian Chopped Liver          chopped walnuts
# 3  Aunt Bev's Vegetarian Chopped Liver  peeled hard boiled eggs
# 4  Aunt Bev's Vegetarian Chopped Liver                     peas

# %%
ingredients_count = {}
for index, row in results_df.iterrows():
    if row.ingredient in ingredients_count:
        if row['name'] not in ingredients_count[row.ingredient]:
            ingredients_count[row.ingredient].append(row['name'])
    else:
        ingredients_count[row.ingredient] = [row['name']]

recipe_count = len(results_df['name'].value_counts())
recipe_count
# Out:
# 168

# %%
frame = results_df.ingredient.value_counts().to_frame()

# %%
frame.reset_index(inplace=True)
final = frame.rename(columns = {'index': 'name'})

# %%
ingredient_proportion = []
for index, item in enumerate(final['name']):
    ingredient_proportion.append(len(ingredients_count[item])/recipe_count)

final['proportion'] = ingredient_proportion

# %%
final.head(20)
# Out:
#                       name  ingredient  proportion
# 0                     salt         271    0.523810
# 1   extra virgin olive oil         181    0.238095
# 2                    sugar          83    0.214286
# 3                 cinnamon          77    0.119048
# 4        fresh lemon juice          72    0.107143
# 5                     eggs          69    0.166667
# 6             black pepper          66    0.119048
# 7                olive oil          63    0.119048
# 8           cayenne pepper          61    0.095238
# 9          unsalted butter          60    0.107143
# 10         Salt and pepper          58    0.101190
# 11          smoked paprika          55    0.095238
# 12                   cumin          53    0.089286
# 13                   water          51    0.166667
# 14                  garlic          50    0.113095
# 15                   honey          46    0.071429
# 16                   onion          42    0.095238
# 17           garlic powder          41    0.065476
# 18             kosher salt          41    0.065476
# 19                 vanilla          40    0.101190

# %%
final.head(10).to_csv('results.csv', index=False)

# %%
results_df.describe()
# Out:
#                                                       url  \
# count                                                5120
# unique                                                168
# top     https://toriavey.com/toris-kitchen/grilled-veg...
# freq                                                  165
#
#                            name ingredient
# count                      5120       5120
# unique                      168        847
# top     Grilled Vegetable Salad       salt
# freq                        165        271

# %%
results_df['ingredient'].value_counts()
# Out:
# salt                      271
# extra virgin olive oil    181
# sugar                      83
# cinnamon                   77
# fresh lemon juice          72
#                          ...
# Yukon Gold potatoes         1
# Manischewitz syrup          1
# chopped celery              1
# yellow onion                1
# vanilla bean paste          1
# Name: ingredient, Length: 847, dtype: int64
